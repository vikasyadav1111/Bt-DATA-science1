# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Pokemon.csv")
data.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
data.shape
# Out:
# (800, 13)

# %%
data.columns = data.columns.str.upper().str.replace('_',' ')
data.head()
# Out:
#    #                   NAME TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
legend = data[data['LEGENDARY']==True]
print(legend)
# Out:
#        #                 NAME    TYPE 1    TYPE 2  TOTAL   HP  ATTACK  \
# 156  144             Articuno       Ice    Flying    580   90      85
# 157  145               Zapdos  Electric    Flying    580   90      90
# 158  146              Moltres      Fire    Flying    580   90     100
# 162  150               Mewtwo   Psychic       NaN    680  106     110
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting    780  106     190
# ..   ...                  ...       ...       ...    ...  ...     ...
# 795  719              Diancie      Rock     Fairy    600   50     100
# 796  719  DiancieMega Diancie      Rock     Fairy    700   50     160
# 797  720  HoopaHoopa Confined   Psychic     Ghost    600   80     110
# 798  720   HoopaHoopa Unbound   Psychic      Dark    680   80     160
# 799  721            Volcanion      Fire     Water    600   80     110
#
#      DEFENSE  SP. ATK  SP. DEF  SPEED  GENERATION  LEGENDARY
# 156      100       95      125     85           1       True
# ...

# %%
#data = data.set_index('NAME')
data.index = data.index.str.replace(".*(?=Mega)"," ")
data.head()
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_10684\3482336852.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   data.index = data.index.str.replace(".*(?=Mega)"," ")
#                 # TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Bulbasaur       1  Grass  Poison    318  45      49       49       65
# Ivysaur         2  Grass  Poison    405  60      62       63       80
# Venusaur        3  Grass  Poison    525  80      82       83      100
#  Mega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander      4   Fire     NaN    309  39      52       43       60
#
#                 SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
# Bulbasaur            65     45           1      False
# Ivysaur              80     60           1      False
# Venusaur            100     80           1      False
#  Mega Venusaur      120     80           1      False
# ...

# %%
filtered = data[((data['TYPE 1']=='Grass') & (data['TYPE 2']=='Dragon'))]
filtered
# Out:
#                   # TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
#  Mega Sceptile  254  Grass  Dragon    630  70     110       75      145
#
#                 SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
#  Mega Sceptile       85    145           3      False

# %%
print("Max HP: ", data['HP'].argmax())
# Out:
# Max HP:  261

# %%
print("Max Defence:",(data['DEFENSE']).idxmax()) #This returns the index of the max value
# Out:
# Max Defence:  Mega Steelix

# %%
data.sort_values('TOTAL',ascending=False).head(3)
# Out:
#                   #   TYPE 1    TYPE 2  TOTAL   HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
#  Mega Rayquaza  384   Dragon    Flying    780  105     180      100      180
#  Mega Mewtwo Y  150  Psychic       NaN    780  106     150       70      194
#  Mega Mewtwo X  150  Psychic  Fighting    780  106     190      100      154
#
#                 SP. DEF  SPEED  GENERATION  LEGENDARY
# NAME
#  Mega Rayquaza      100    115           3       True
#  Mega Mewtwo Y      120    140           1       True
#  Mega Mewtwo X      100    130           1       True

# %%
#data2 = data.drop(['GENERATION','TOTAL'],axis=1)
data3 = data2.drop(['#'],axis=1)
data3.head()
# Out:
#                TYPE 1  TYPE 2  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  SPEED  \
# NAME
# Bulbasaur       Grass  Poison  45      49       49       65       65     45
# Ivysaur         Grass  Poison  60      62       63       80       80     60
# Venusaur        Grass  Poison  80      82       83      100      100     80
#  Mega Venusaur  Grass  Poison  80     100      123      122      120     80
# Charmander       Fire     NaN  39      52       43       60       50     65
#
#                 LEGENDARY
# NAME
# Bulbasaur           False
# Ivysaur             False
# Venusaur            False
#  Mega Venusaur      False
# Charmander          False

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   TYPE 1      800 non-null    object
#  2   TYPE 2      414 non-null    object
#  3   TOTAL       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   ATTACK      800 non-null    int64
#  6   DEFENSE     800 non-null    int64
#  7   SP. ATK     800 non-null    int64
#  8   SP. DEF     800 non-null    int64
#  9   SPEED       800 non-null    int64
#  10  GENERATION  800 non-null    int64
#  11  LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 75.8+ KB

# %%
import seaborn as sns
sns.boxplot(data=data3)
plt.ylim(0,300)
plt.show()

# %%
print("Best Pokemon for attack is :",(data['ATTACK']).idxmax()) #This returns the index of the max value
# Out:
# Best Pokemon for attack is :  Mega Mewtwo X

# %%
data_new = np.random.rand(5,5)
plt.imshow(data_new,cmap='hot')
plt.colorbar()
plt.title('Heatmap')
plt.show()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   TYPE 1      800 non-null    object
#  2   TYPE 2      414 non-null    object
#  3   TOTAL       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   ATTACK      800 non-null    int64
#  6   DEFENSE     800 non-null    int64
#  7   SP. ATK     800 non-null    int64
#  8   SP. DEF     800 non-null    int64
#  9   SPEED       800 non-null    int64
#  10  GENERATION  800 non-null    int64
#  11  LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 75.8+ KB

# %%
data_cleaned = data.dropna()
data_filled_mean = data.fillna(data.mean)
data_filled_median = data.fillna(data.median)

# %%
data_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 414 entries, Bulbasaur to Volcanion
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           414 non-null    int64
#  1   TYPE 1      414 non-null    object
#  2   TYPE 2      414 non-null    object
#  3   TOTAL       414 non-null    int64
#  4   HP          414 non-null    int64
#  5   ATTACK      414 non-null    int64
#  6   DEFENSE     414 non-null    int64
#  7   SP. ATK     414 non-null    int64
#  8   SP. DEF     414 non-null    int64
#  9   SPEED       414 non-null    int64
#  10  GENERATION  414 non-null    int64
#  11  LEGENDARY   414 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 39.2+ KB

# %%
data_filled_median.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   TYPE 1      800 non-null    object
#  2   TYPE 2      800 non-null    object
#  3   TOTAL       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   ATTACK      800 non-null    int64
#  6   DEFENSE     800 non-null    int64
#  7   SP. ATK     800 non-null    int64
#  8   SP. DEF     800 non-null    int64
#  9   SPEED       800 non-null    int64
#  10  GENERATION  800 non-null    int64
#  11  LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 75.8+ KB

# %%
data_filled_mean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 800 entries, Bulbasaur to Volcanion
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   TYPE 1      800 non-null    object
#  2   TYPE 2      800 non-null    object
#  3   TOTAL       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   ATTACK      800 non-null    int64
#  6   DEFENSE     800 non-null    int64
#  7   SP. ATK     800 non-null    int64
#  8   SP. DEF     800 non-null    int64
#  9   SPEED       800 non-null    int64
#  10  GENERATION  800 non-null    int64
#  11  LEGENDARY   800 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 75.8+ KB

# %%
data_duplicates = data.drop_duplicates()
data_duplicates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 798 entries, Bulbasaur to Volcanion
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           798 non-null    int64
#  1   TYPE 1      798 non-null    object
#  2   TYPE 2      413 non-null    object
#  3   TOTAL       798 non-null    int64
#  4   HP          798 non-null    int64
#  5   ATTACK      798 non-null    int64
#  6   DEFENSE     798 non-null    int64
#  7   SP. ATK     798 non-null    int64
#  8   SP. DEF     798 non-null    int64
#  9   SPEED       798 non-null    int64
#  10  GENERATION  798 non-null    int64
#  11  LEGENDARY   798 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 75.6+ KB

# %%
# columns_to_drop = ['ATTACK','DEFENSE','SPEED']
# data_columns_to_drop = data.drop(columns=columns_to_drop)

# %%
data['TRANSFORM'] = np.log(data['SPEED'])
data.head()
# Out:
#                 # TYPE 1  TYPE 2  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  \
# NAME
# Bulbasaur       1  Grass  Poison    318  45      49       49       65
# Ivysaur         2  Grass  Poison    405  60      62       63       80
# Venusaur        3  Grass  Poison    525  80      82       83      100
#  Mega Venusaur  3  Grass  Poison    625  80     100      123      122
# Charmander      4   Fire     NaN    309  39      52       43       60
#
#                 SP. DEF  SPEED  GENERATION  LEGENDARY  TRANSFORM
# NAME
# Bulbasaur            65     45           1      False   3.806662
# Ivysaur              80     60           1      False   4.094345
# Venusaur            100     80           1      False   4.382027
#  Mega Venusaur      120     80           1      False   4.382027
# Charmander           50     65           1      False   4.174387

# %%
data_encoded = pd.get_dummies(data,columns = ['TYPE 1','TYPE 2'])
data_encoded
# Out:
#                        #  TOTAL  HP  ATTACK  DEFENSE  SP. ATK  SP. DEF  SPEED  \
# NAME
# Bulbasaur              1    318  45      49       49       65       65     45
# Ivysaur                2    405  60      62       63       80       80     60
# Venusaur               3    525  80      82       83      100      100     80
#  Mega Venusaur         3    625  80     100      123      122      120     80
# Charmander             4    309  39      52       43       60       50     65
# ...                  ...    ...  ..     ...      ...      ...      ...    ...
# Diancie              719    600  50     100      150      100      150     50
#  Mega Diancie        719    700  50     160      110      160      110    110
# HoopaHoopa Confined  720    600  80     110       60      150      130     70
# HoopaHoopa Unbound   720    680  80     160       60      170      130     80
# Volcanion            721    600  80     110      120      130       90     70
#
# ...
